# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# !mongoimport --type json -d uk_food -c establishments --drop --jsonArray Resources/establishments.json
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
# Out:
# 2024-07-21T14:35:20.216-0500	connected to: mongodb://localhost/
# 2024-07-21T14:35:20.217-0500	dropping: uk_food.establishments
# 2024-07-21T14:35:21.422-0500	39779 document(s) imported successfully. 0 document(s) failed to import.

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
pprint(mongo.list_database_names())
# Out:
# ['admin',
#  'autosaurus',
#  'classDB',
#  'config',
#  'crime_db',
#  'local',
#  'met',
#  'petsitly_marketing',
#  'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one(), indent=3)
# Out:
# {  'AddressLine1': 'The Bay',
#    'AddressLine2': 'St Margarets Bay',
#    'AddressLine3': 'Kent',
#    'AddressLine4': '',
#    'BusinessName': 'The Coastguard Inn',
#    'BusinessType': 'Pub/bar/nightclub',
#    'BusinessTypeID': 7843,
#    'ChangesByServerID': 0,
#    'Distance': 4587.347174863443,
#    'FHRSID': 1034540,
#    'LocalAuthorityBusinessID': 'PI/000078691',
#    'LocalAuthorityCode': '182',
#    'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#    'LocalAuthorityName': 'Dover',
#    'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#    'NewRatingPending': False,
#    'Phone': '',
#    'PostCode': 'CT15 6DY',
#    'RatingDate': '2022-08-17T00:00:00',
#    'RatingKey': 'fhrs_5_en-gb',
#    'RatingValue': '5',
#    'RightToReply': '',
#    'SchemeType': 'FHRS',
#    '_id': ObjectId('669d62f8ea202190e8afc3af'),
#    'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#    'links': [  {  'href': 'https://api.ratings.food.gov.uk/establishments/1034540',
#                   'rel': 'self'}],
#    'meta': {  'dataSource': None,
#               'extractDate': '0001-01-01T00:00:00',
#               'itemCount': 0,
#               'pageNumber': 0,
#               'pageSize': 0,
#               'returncode': None,
#               'totalCount': 0,
#               'totalPages': 0},
#    'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
penang_flavours = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
db.establishments.insert_one(penang_flavours)
# Out:
# InsertOneResult(ObjectId('669d62fa78a7cf33f672990d'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
query = {"BusinessName": {"$regex": "Penang Flavours"}}

# Capture the results to a variable
results = db.establishments.find(query)

# Iterate over the results and print each document
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('669d62fa78a7cf33f672990d'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {"BusinessType": "Restaurant/Cafe/Canteen"}
result = db.establishments.find(query, {"BusinessTypeID", "BusinessType"})


pprint(list(result),indent=3)
# Out:
# [  {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3b0')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3b7')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3b9')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3ba')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3bc')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3c0')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3c2')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3c3')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3c4')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3c5')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3c6')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3c7')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3cc')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3cf')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3d4')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3df')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3e1')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3e2')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3e3')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3e6')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3ea')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3eb')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3ed')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3ee')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3ef')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3f0')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3f1')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3f5')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3fa')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc3fe')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc401')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc402')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc403')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc406')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc409')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc40c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc40d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc411')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc414')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc415')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc417')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc41a')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc41b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc41c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc428')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc42e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc430')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc433')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc434')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc436')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc437')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc438')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc43f')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc448')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc449')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc44d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc451')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc452')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc461')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc463')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc466')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc46a')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc46f')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc471')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc472')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc477')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc47c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc47f')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc481')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc483')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc484')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc485')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc486')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc48c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4a3')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4a4')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4a5')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4a8')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4ae')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4ba')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4bd')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4c2')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4c3')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4c5')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4c6')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4c8')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4cc')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4cf')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4d2')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4d8')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4df')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4e0')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4e3')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4e6')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4eb')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4ec')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4ee')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4f4')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4f6')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4f9')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4fa')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4fb')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4fd')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc4fe')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc505')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc506')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc508')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc512')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc514')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc517')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc51a')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc51b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc51c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc51e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc51f')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc521')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc522')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc528')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc529')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc52c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc530')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc531')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc532')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc539')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc53a')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc53b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc545')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc547')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc548')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc54d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc550')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc552')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc553')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc557')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc55c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc55e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc566')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc56d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc570')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc577')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc578')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc57c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc580')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc582')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc589')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc592')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc5a0')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc5aa')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc5bf')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc5ce')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc5d5')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc5e3')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc5f5')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc607')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc60d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc613')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc616')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc61d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc61f')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc621')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc623')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc633')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc641')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc648')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc64b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc64f')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc653')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc654')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc65c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc65f')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc660')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc662')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc665')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc666')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc66b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc672')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc677')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc67d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc683')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc684')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc688')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc692')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc697')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc69e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6a0')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6a1')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6ac')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6b4')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6bd')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6c2')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6c6')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6c8')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6c9')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6cb')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6dc')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6e1')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6e5')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6eb')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6ed')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6f0')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6f1')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6f7')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6f8')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6f9')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6fa')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6fb')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc6fd')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc704')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc706')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc707')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc709')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc70b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc70e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc70f')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc712')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc715')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc718')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc71f')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc725')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc727')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc729')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc72b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc72c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc72e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc732')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc733')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc735')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc73a')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc73c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc73d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc73e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc745')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc746')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc74b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc74c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc74e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc751')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc757')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc75c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc75d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc764')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc765')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc766')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc768')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc76e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc772')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc774')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc776')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc779')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc77d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc781')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc782')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc783')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc785')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc788')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc78f')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc791')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc792')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc793')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc79b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc79c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc79e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7a1')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7a2')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7a8')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7a9')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7aa')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7ab')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7ae')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7af')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7b2')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7b5')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7b6')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7bb')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7c1')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7c2')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7c6')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7e3')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7e9')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7ec')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7f1')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7f6')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7fc')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc7ff')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc80d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc815')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc817')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc81a')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc81d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc821')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc822')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc823')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc824')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc825')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc826')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc82c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc82d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc82e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc82f')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc830')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc833')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc834')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc838')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc845')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc84a')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc84c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc84d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc84e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc851')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc853')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc854')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc855')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc857')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc858')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc859')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc85d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc85e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc868')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc86a')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc86b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc86c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc86d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc86f')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc879')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc87f')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc880')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc881')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc882')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc884')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc887')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc888')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc889')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc88c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc891')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc894')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc899')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc89d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8a3')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8a5')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8a7')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8a9')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8ad')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8b7')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8bd')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8c0')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8c1')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8c5')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8c8')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8cb')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8ce')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8d7')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8da')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8e0')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8e1')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8e3')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8e5')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8e8')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8ed')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8f1')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8f3')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8f5')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc8fc')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc900')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc903')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc904')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc908')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc90a')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc90b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc90c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc90d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc90e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc911')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc912')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc913')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f8ea202190e8afc914')},
# ...
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d29')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d2a')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d2b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d2d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d33')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d34')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d35')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d38')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d39')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d3a')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d3b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d3d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d46')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d47')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d4a')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d4b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d4c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d4d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d4f')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d50')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d55')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d57')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d61')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d62')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d64')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d68')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d6e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d71')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d79')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d7a')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d7b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05d85')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05da4')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05dac')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05db1')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05db5')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05db6')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05db8')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05dbc')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05dbd')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05dbe')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05dbf')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05dc2')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05dc3')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05dc5')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05dd5')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05dda')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05de4')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05de6')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05deb')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05dec')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05df7')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05dfa')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05dfd')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e02')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e04')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e06')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e07')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e0a')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e18')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e1f')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e23')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e30')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e34')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e37')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e39')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e3f')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e41')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e44')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e4d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e4e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e52')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e55')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e5c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e61')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e63')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e64')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e65')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e68')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e6a')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e6b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e6c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e6e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e71')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e72')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e73')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e77')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e79')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e7b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e7c')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e7d')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e7f')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e80')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e81')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e82')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e85')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e8a')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e8b')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e91')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e92')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e94')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e96')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e9a')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05e9e')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05ea2')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05ea5')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05eb1')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05eb6')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05eb7')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05eb9')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05ebe')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05ec0')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05ecb')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05ed5')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05ed8')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05ede')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05eec')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05ef1')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05ef6')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05ef8')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05efc')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05f01')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05f03')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': 1,
#       '_id': ObjectId('669d62f9ea202190e8b05f10')},
#    {  'BusinessType': 'Restaurant/Cafe/Canteen',
#       'BusinessTypeID': '',
#       '_id': ObjectId('669d62fa78a7cf33f672990d')}]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
filter_query = {"BusinessName": "Penang Flavours"}
update_query = {"$set": {"BusinessTypeID": "1"}}

# Execute update_one operation
update_result = db.establishments.update_one(filter_query, update_query)

# %%
# Confirm that the new restaurant was updated
if update_result.modified_count > 0:
    print("'Penang Flavours' has been updated with the correct BusinessTypeID.")
else:
    print("Penang Flavours was NOT updated.")
# Out:
# 'Penang Flavours' has been updated with the correct BusinessTypeID.

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
documents = {"LocalAuthorityName": "Dover"}

# Count documents that match query
count = db.establishments.count_documents(documents)
print(count)
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
documents = {"LocalAuthorityName": "Dover"}

# Delete all documents that match query
delete_result = db.establishments.delete_many(documents)
counts_after = db.establishments.count_documents(documents)
print(counts_after)
# Out:
# 0

# %%
# Check if any remaining documents include Dover

# Find how many documents now have LocalAuthorityName as "Dover"
documents = {"LocalAuthorityName": "Dover"}

# Count current documents that match query
count = db.establishments.count_documents(documents)
print(count)
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
docs = db.establishments.find_one()
pprint(docs)

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude

db.establishments.update_many({}, [
    {"$set": {
        "geocode.latitude": {"$toDouble": "$geocode.latitude"},
        "geocode.longitude": {"$toDouble": "$geocode.longitude"}
    }}
])
# Out:
# UpdateResult({'n': 38786, 'nModified': 38786, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4091, 'nModified': 4091, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
db.establishments.update_many({},[
    {"$set": {
        "RatingValue": {"$toInt": "$RatingValue"}
    }}
])
# Out:
# UpdateResult({'n': 38786, 'nModified': 34695, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
geo_check = db.establishments.find_one()
#pprint(geo_check)
# Check the data type of RatingValue
ratingvalue_check = db.establishments.find_one()
pprint(ratingvalue_check)
# Out:
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('669d62f8ea202190e8afc694'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}

# %%
# Check that the coordinates and rating value are now numbers
# check = establishments.find_one()
# for key, value in check.items():
#     if isinstance(value, dict):
#         print(f"Field: {key}, Data Type: {type(value)}")
#         for sub_key, sub_value in value.items():
#             print(f"  Subfield: {sub_key}, Data Type: {type(sub_value)}, Value: {sub_value}")
#     else:
#         print(f"Field: {key}, Data Type: {type(value)}, Value: {value}")
